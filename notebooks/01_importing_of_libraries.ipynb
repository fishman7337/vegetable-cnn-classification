# %% [markdown]
# ---
# # 1. Importing of Libaries
# ---

# %% [markdown]
# In this section, we will be importing all the required Libaries of the Deep Learning CA1. Most of the libaries will be from TensorFlow, Keras and various Data Analysis and Visualisation Libaries. These Libaries will be imported in the code cell below.

# %%
# ==================== Installing Keras Tuner ==================== #
# !pip install -q keras-tuner

# ==================== Installing Keras Visual ==================== #
# !pip install -q visualkeras

# ==================== Importing Keras Models ==================== #
from tensorflow.keras.models import Sequential, Model, load_model

# ==================== Importing Keras Layers ==================== #
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, Add, Activation, SeparableConv2D, Concatenate

# ==================== Importing Keras Regulariser ==================== #
from tensorflow.keras.regularizers import l2

# ==================== Importing Keras Regulariser ==================== #
from tensorflow.keras import regularizers

# ==================== Importing Keras Optimiser ==================== #
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

# ==================== Importing Keras Tuner ==================== #
import keras_tuner as kt

# ==================== Importing Keras Image Data Generator ==================== #
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ==================== Importing Sklearn Confusion Matrix ==================== #
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_curve, auc

# ==================== Importing Keras Callbacks ==================== #
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint

# ==================== Importing Matplotlib ==================== #
import matplotlib.pyplot as plt

# ==================== Importing Seaborn ==================== #
import seaborn as sns

# ==================== Importing Pandas ==================== #
import pandas as pd

# ==================== Importing NumPy ==================== #
import numpy as np

# ==================== Importing Operating System ==================== #
import os

# ==================== Importing Computer Vision 2 ==================== #
import cv2

# ==================== Importing TSNE ==================== #
from sklearn.manifold import TSNE

# ==================== Importing Plotly ==================== #
import plotly.express as px

# ==================== Importing Keras Utility ==================== #
from tensorflow.keras.utils import to_categorical, plot_model


# ==================== Importing Visual Keras ==================== #
import visualkeras

# ==================== Importing Image ==================== #
from IPython.display import Image

# ==================== Mounting Google Drive ==================== #
from google.colab import drive
drive.mount('/content/drive')

# ==================== Importing Shutill ==================== #
import shutil

# ==================== Defining Paths ==================== #
DRIVE_ROOT = '/content/drive/MyDrive/Colab Notebooks/DELE CA1 A'
LOCAL_ROOT = '/content/DELE_CA1 A'

# ==================== Copying Project Folder To Local SSD ==================== #
if os.path.exists(LOCAL_ROOT):
    shutil.rmtree(LOCAL_ROOT)
shutil.copytree(DRIVE_ROOT, LOCAL_ROOT)

# ==================== Switching To Local SSD ==================== #
os.chdir(LOCAL_ROOT)
print("Now working in:", os.getcwd())

# ==================== Final Confirmation ==================== #
print("Libaries Imported Successfully")

# %% [markdown]
# With reference to the output above, we are able to confirm that the Libaries
# have been successfully imported and we can move on to loading the dataset provided.
